# %%
import pandas as pd

pd.options.display.max_columns = 100
pd.options.display.max_rows = 64

# %%
import pandas as pd
from sklearn.datasets import make_classification

data, target = make_classification(n_samples=100, n_features=5, random_state=42)

columns = [f"feature_{i}" for i in range(data.shape[1])]
df = pd.DataFrame(data, columns=columns)
df['target'] = target

# первые пять строк
print(df.head())

print('-'*30)

# последние пять строк
print(df.tail())
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  target
# 0  -0.430668   0.672873  -0.724280  -0.539630  -0.651600       0
# 1   0.211646  -0.843897   0.534794   0.825848   0.681953       1
# 2   1.092675   0.409106   1.100096  -0.942751  -0.981509       0
# 3   1.519901  -0.773361   1.998053   0.155132  -0.385314       0
# 4  -0.453901  -2.183473   0.244724   2.591239  -0.484234       1
# ------------------------------
#     feature_0  feature_1  feature_2  feature_3  feature_4  target
# 95   0.735948   1.203166   0.417673  -1.648321  -0.151785       0
# 96   0.846092  -1.140526   1.359706   0.861991   0.629629       1
# 97  -0.844677   1.643195  -1.533275  -1.411759  -1.612716       0
# 98  -1.282744   0.120370  -1.500776   0.450590   2.122156       1
# 99  -0.722168  -1.128686  -0.427958   1.560704  -1.024388       1

# %%
print(df.describe())
# Out:
#         feature_0   feature_1   feature_2   feature_3   feature_4      target
# count  100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# mean    -0.031206    0.038332   -0.048848   -0.027714    0.029213    0.500000
# std      0.894988    1.274375    1.230126    1.323957    1.007244    0.502519
# min     -1.692005   -2.683180   -2.523434   -2.585909   -3.241267    0.000000
# 25%     -0.819243   -0.989945   -1.097573   -1.185113   -0.629925    0.000000
# 50%      0.098274   -0.098046   -0.035241    0.069846    0.054926    0.500000
# 75%      0.707311    1.190847    1.035708    1.089659    0.701519    1.000000
# max      1.724002    2.489048    2.388694    2.591239    2.314659    1.000000

# %%
print(df.isnull().sum().sort_values(ascending=False))
print(df.notna().sum().sort_values(ascending=False))
# Out:
# feature_0    0
# feature_1    0
# feature_2    0
# feature_3    0
# feature_4    0
# target       0
# dtype: int64
# feature_0    100
# feature_1    100
# feature_2    100
# feature_3    100
# feature_4    100
# target       100
# dtype: int64

# %%
df.dtypes
# Out:
# feature_0    float64
# feature_1    float64
# feature_2    float64
# feature_3    float64
# feature_4    float64
# target         int64
# dtype: object

# %%
import pandas as pd
import numpy as np

# сгенерируем небольшой набор данных для примера
data = {
    'Category': ['Electronics', 'Clothing', 'Electronics', 'Clothing', 'Electronics', 
                 'Clothing', 'Electronics', 'Electronics', 'Clothing', 'Electronics', 
                 'Clothing', 'Electronics', 'Clothing', 'Electronics', 'Clothing'],
    'Sales': [400, 300, 450, 200, 500, 550, 330, 480, 520, 350, 420, 290, 390, 410, 380]
}

df = pd.DataFrame(data)
# ваш код для агрегации данных
aggregated_df = df.groupby('Category').agg({'Sales': 'mean'}).reset_index() 

# ваш код для сортировки данных
sorted_df = aggregated_df.sort_values(by="Sales", ascending=False)
sorted_df.reset_index(drop=True, inplace=True)
print(sorted_df)
# Out:
#       Category       Sales
# 0  Electronics  401.250000
# 1     Clothing  394.285714

# %%
aggregated_df
# Out:
#       Category       Sales
# 0     Clothing  394.285714
# 1  Electronics  401.250000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# загрузка данных
data = sns.load_dataset("tips")

# построение гистограммы
sns.histplot(data=data, x="total_bill", kde=True)
plt.title('Гистограмма распределения чека')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# загрузка данных
data = sns.load_dataset("diamonds")

# построение boxplot
sns.boxplot(data=data, x="cut", y="price",)
plt.title('Сравнение цен на недвижимость по типу камня')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# загрузка данных
data = sns.load_dataset("planets")
# data_agg = data.groupby("year").agg({"number":"sum"}).reset_index()
sns.catplot(
    data=data, 
    kind="count",
    x="year",
)
plt.title('Количество обнаруженных экзопланет в каждом году')
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# загрузка данных
data = sns.load_dataset("planets")
sns.lineplot(
    data=data, 
    x="year",
    y="orbital_period"
)
plt.xticks(rotation=45)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# загрузка данных
sns.histplot(
    data=data.dropna(subset='mass'), 
    x="mass",
    kde = True
)

plt.xticks(rotation=45)
plt.show()

# %%
data.dropna(subset='mass').reset_index()
# Out:
#      index           method  number  orbital_period    mass  distance  year
# 0        0  Radial Velocity       1         269.300   7.100     77.40  2006
# 1        1  Radial Velocity       1         874.774   2.210     56.95  2008
# 2        2  Radial Velocity       1         763.000   2.600     19.84  2011
# 3        3  Radial Velocity       1         326.030  19.400    110.62  2007
# 4        4  Radial Velocity       1         516.220  10.500    119.47  2009
# ..     ...              ...     ...             ...     ...       ...   ...
# 508    784  Radial Velocity       3         580.000   0.947    135.00  2012
# 509    913  Radial Velocity       1         677.800  19.800       NaN  2007
# 510    914  Radial Velocity       1           6.958   0.340       NaN  2014
# 511    915  Radial Velocity       1           5.118   0.400       NaN  2014
# 512    916  Radial Velocity       1         121.710   1.540       NaN  2014
#
# [513 rows x 7 columns]
